# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution, where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %% [markdown]
# DISTRIBUCIÓN NORMAL

# %%
from scipy.stats import norm

def dnorm(x, mean = 0, std = 1):
    """
    Calcula la densidad de probabilidad de la distribución normal.
    """
    result = norm.pdf(x = x, loc = mean, scale = std)

    return result


def pnorm(q, mean = 0, std = 1):
    """
    Calcula la probabilidad acumulada de la distribución normal.
    """
    result = norm.cdf(x = q, loc = mean, scale = std)

    return result


def qnorm(p, mean = 0, std = 1):
    """
    Calcula el cuantil de la distribución normal.
    """
    result = norm.ppf(q = p, loc = mean, scale = std)

    return result


def rnorm(n, mean = 0, std = 1):
    """
    Genera variables aleatorias a partir de la distribución normal.
    """
    result = norm.rvs(loc = mean, scale = std, size = n)

    return result

import numpy as np

np.random.seed(42)

print(f"La densida de probabilidad de la distribución normal es de: {dnorm(2, mean = 10, std = 0.2)}")
print(f"La probabilidad acumulada de la distribución normal es de: {pnorm(2, mean = 10, std = 0.2)}")
print(f"El cuantil es igual a: {qnorm(0.9, mean = 10, std = 0.2)}")
print(f"Las variables aleatorias de la distribución normal es igual a: {rnorm(2000, mean = 10, std = 0.2)}")
# Out:
# La densida de probabilidad de la distribución normal es de: 0.0
# La probabilidad acumulada de la distribución normal es de: 0.0
# El cuantil es igual a: 10.25631031310892
# Las variables aleatorias de la distribución normal es igual a: [10.09934283  9.97234714 10.12953771 ...  9.82362507  9.96738661
#   9.85101947]

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

mean = 0
std = 1
data = np.arange(-5, 5, 0.01)

pdf = dnorm(data, mean = mean, std = std)
cdf = pnorm(data, mean = mean, std = std)
pmf = qnorm(cdf, mean = mean, std = std)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].plot(data, pdf, "r-")
axis[1].plot(data, cdf, "b-")
axis[2].plot(data, pmf, "g-")

plt.tight_layout()

plt.show()

# %% [markdown]
# DISTRIBUCIÓN UNIFORME

# %%
from scipy.stats import uniform

def dunif(x, low = 0, high = 1):
    """
    Calcula la densidad de probabilidad de la distribución uniforme.
    """
    result = uniform.pdf(x = x, loc = low, scale = high - low)

    return result


def punif(q, low = 0, high = 1):
    """
    Calcula el acumulado de la distribución uniforme.
    """
    result = uniform.cdf(x = q, loc = low, scale = high - low)

    return result


def qunif(p, low = 0, high = 1):
    """
    Calcula la función cuantil de la distribución uniforme.
    """
    result = uniform.ppf(q = p, loc = low, scale = high - low)

    return result


def runif(n, low = 0, high = 1):
    """
    Genera variables aleatorias a partir de la distribución uniforme.
    """
    result = uniform.rvs(loc = low, scale = high - low, size = n)

    return result

import numpy as np

np.random.seed(42)

print(f"La densidad de probabilidad de la distribución uniforme es: {dunif(0.5, low = 0, high = 1)}")
print(f"La probabilidad acumulada de la distribución uniforme es: {punif(0.5, low = 0, high = 1)}")
print(f"El cuantil de la distribución uniforme es: {qunif(0.9, low = 0, high = 1)}")
print(f"Las variables aleatorias generadas de la distribución uniforme son: {runif(10, low = 0, high = 1)}")
# Out:
# La densidad de probabilidad de la distribución uniforme es: 1.0
# La probabilidad acumulada de la distribución uniforme es: 0.5
# El cuantil de la distribución uniforme es: 0.9
# Las variables aleatorias generadas de la distribución uniforme son: [0.37454012 0.95071431 0.73199394 0.59865848 0.15601864 0.15599452
#  0.05808361 0.86617615 0.60111501 0.70807258]

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

low = 0
high = 1
data = np.arange(-0.5, 1.5, 0.01)

pdf = dunif(data, low = low, high = high)
cdf = punif(data, low = low, high = high)
pmf = qunif(cdf, low = low, high = high)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].plot(data, pdf, "r-")
axis[1].plot(data, cdf, "b-")
axis[2].plot(data, pmf, "g-")

plt.tight_layout()

plt.show()
